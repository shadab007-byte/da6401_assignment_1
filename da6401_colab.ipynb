# %% [markdown]
# <a href="https://colab.research.google.com/github/shadab007-byte/da6401_assignment_1/blob/main/da6401_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DA6401 Assignment 1 — MLP for Image Classification
# **Author:** Mohd Shadab | **Roll:** MA24M015
#
# ## What this notebook does (in order):
# 1. Setup: clone repo, install packages, login to W&B
# 2. **Q2.1** — Data exploration table (5 images × 10 classes)
# 3. **Q2.2** — Hyperparameter sweep (100 runs, Bayesian)
# 4. **Q2.3** — Optimizer showdown (all 6 optimizers)
# 5. **Q2.4** — Vanishing gradient: Sigmoid vs ReLU
# 6. **Q2.5** — Dead neuron investigation (high LR + ReLU vs Tanh)
# 7. **Q2.6** — Cross-entropy vs MSE comparison
# 8. **Q2.7** — Global train vs val accuracy scatter
# 9. **Q2.8** — Confusion matrix + creative error visualization
# 10. **Q2.9** — Zeros vs Xavier symmetry breaking
# 11. **Q2.10** — Fashion-MNIST transfer challenge
# 12. Save best model + run inference + commit to GitHub

# %% [markdown]
# ---
# # STEP 1: Setup

# %%
import os
os.environ["WANDB_ENTITY"] = "iitm_assigment"

GITHUB_USERNAME = 'shadab007-byte'
WANDB_PROJECT   = 'da6401-assignment-1'
WANDB_ENTITY    = 'iitm_assigment'

# Clone repository
import os
if not os.path.exists('da6401_assignment_1'):
    # !git clone https://github.com/{GITHUB_USERNAME}/da6401_assignment_1.git
# %cd da6401_assignment_1
# !ls src/ann/
# Out:
# Cloning into 'da6401_assignment_1'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 104 (delta 31), reused 59 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 51.66 KiB | 1.20 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/da6401_assignment_1
# activations.py	neural_layer.py    objective_functions.py
# __init__.py	neural_network.py  optimizers.py

# %%
# !pip install wandb scikit-learn keras tensorflow -q
print('Packages installed!')
# Out:
# Packages installed!

# %%
import wandb

wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ma24m015 (iitm_assigment) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import sys
sys.path.insert(0, 'src')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import json, os
from sklearn.metrics import confusion_matrix

from ann.neural_network import NeuralNetwork
from ann.optimizers import get_optimizer
from utils.data_loader import load_dataset, to_onehot, get_batches, get_class_names
from utils.metrics import compute_metrics, get_confusion_matrix

print('✓ All imports successful!')
# Out:
# ✓ All imports successful!

# %%
#load both datasets
print('Loading MNIST...')
X_tr, y_tr, X_val, y_val, X_te, y_te = load_dataset('mnist')
y_tr_oh  = to_onehot(y_tr)
y_val_oh = to_onehot(y_val)
y_te_oh  = to_onehot(y_te)

print('Loading Fashion-MNIST...')
X_tr_f, y_tr_f, X_val_f, y_val_f, X_te_f, y_te_f = load_dataset('fashion_mnist')
y_tr_f_oh  = to_onehot(y_tr_f)
y_val_f_oh = to_onehot(y_val_f)

print('\n✓ Both datasets loaded!')
# Out:
# Loading MNIST...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [info] mnist → Train:54000, Val:6000, Test:10000
# Loading Fashion-MNIST...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [info] fashion_mnist → Train:54000, Val:6000, Test:10000
#
# ✓ Both datasets loaded!

# %%
import argparse

def build_and_train(
    X_train, y_train_oh, X_val, y_val_oh, y_val_int,
    hidden_sizes, activation, optimizer_name, learning_rate,
    weight_init='xavier', loss_name='cross_entropy',
    epochs=10, batch_size=64, weight_decay=0.0,
    log_grad_norms=False, log_activations=False,
    use_wandb=True
):
    """Build model, attach optimizer, train, log to W&B. Returns (model, history)."""

    #build CLI-args namespace
    args = argparse.Namespace(
        num_layers=len(hidden_sizes),
        hidden_size=hidden_sizes,
        activation=activation,
        weight_init=weight_init,
        loss=loss_name,
        weight_decay=weight_decay,
    )
    model = NeuralNetwork(cli_args=args)

    #optimizer setup
    opt_kw = dict(learning_rate=learning_rate, weight_decay=weight_decay)
    if optimizer_name in ['momentum', 'nag']:
        opt_kw['beta'] = 0.9
    elif optimizer_name == 'rmsprop':
        opt_kw['beta'] = 0.9; opt_kw['eps'] = 1e-8
    elif optimizer_name in ['adam', 'nadam']:
        opt_kw['beta1'] = 0.9; opt_kw['beta2'] = 0.999; opt_kw['eps'] = 1e-8

    model.optimizer = get_optimizer(optimizer_name, **opt_kw)
    use_nag = model.optimizer.is_nag  # True only for NAG

    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}

    for epoch in range(1, epochs + 1):
        losses = []
        for Xb, yb in get_batches(X_train, y_train_oh, batch_size):

            if use_nag:
                model.optimizer.apply_lookahead(model.layers)
            logits = model.forward(Xb)
            model.backward(yb, logits)
            model.update_weights()
            losses.append(model._last_loss)

        train_loss = float(np.mean(losses))
        train_acc  = float(np.mean(model.predict(X_train) == np.argmax(y_train_oh, 1)))

        val_logits = model.forward(X_val)
        from ann.objective_functions import get_loss as _gl
        val_loss, _ = _gl(loss_name)(val_logits, y_val_oh)
        val_acc     = float(np.mean(model.predict(X_val) == y_val_int))

        history['train_loss'].append(train_loss)
        history['val_loss'].append(float(val_loss))
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)

        log_dict = {
            'epoch': epoch,
            'train_loss': train_loss, 'val_loss': float(val_loss),
            'train_accuracy': train_acc, 'val_accuracy': val_acc
        }
        if log_grad_norms:
            for name, norm in model.get_gradient_norms():
                log_dict[name] = norm
        if log_activations:
            log_dict.update(model.get_activation_stats())
        if use_wandb:
            wandb.log(log_dict)

        if epoch % 5 == 0 or epoch == 1:
            print(f'  Ep {epoch:3d} | loss={train_loss:.4f} | val_acc={val_acc:.4f}')

    return model, history

print('✓ Helper defined!')
# Out:
# ✓ Helper defined!

# %% [markdown]
# ---
# # Q2.1 — Data Exploration & Class Distribution (3 Marks)
# **What to do:** Log a W&B Table with 5 sample images from each of the 10 classes.

# %%
fashion_cls = get_class_names('fashion_mnist')

run = wandb.init(project=WANDB_PROJECT, name='q2-1-data-exploration', job_type='data')

#W&B Table: 5 images per class ──
cols  = ['class_id', 'class_name'] + [f'sample_{i+1}' for i in range(5)]
table = wandb.Table(columns=cols)

for cid in range(10):
    idxs   = np.where(y_tr_f == cid)[0][:5]
    wb_imgs = [wandb.Image((X_tr_f[i].reshape(28,28)*255).astype(np.uint8),
                            caption=fashion_cls[cid]) for i in idxs]
    table.add_data(cid, fashion_cls[cid], *wb_imgs)

wandb.log({'class_sample_table': table})

#class distribution bar chart
unique, counts = np.unique(y_tr_f, return_counts=True)
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
axes[0].bar([fashion_cls[i] for i in unique], counts, color='steelblue')
axes[0].set_title('Class Distribution (Fashion-MNIST Train)')
axes[0].set_xticklabels([fashion_cls[i] for i in unique], rotation=45, ha='right')
axes[0].set_ylabel('Count')

#grid: 5 images × 10 classes
axes[1].axis('off')

fig2, ax2 = plt.subplots(10, 5, figsize=(8, 16))
for cid in range(10):
    idxs = np.where(y_tr_f == cid)[0][:5]
    for j, idx in enumerate(idxs):
        ax2[cid, j].imshow(X_tr_f[idx].reshape(28,28), cmap='gray')
        ax2[cid, j].axis('off')
    ax2[cid, 0].set_ylabel(fashion_cls[cid], fontsize=8, rotation=0, ha='right', labelpad=40)
plt.suptitle('Fashion-MNIST: 5 Samples Per Class', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('class_grid.png', dpi=100, bbox_inches='tight')
wandb.log({'class_grid': wandb.Image('class_grid.png')})
plt.show()

wandb.finish()
print('✓ Q2.1 Done! W&B project → Runs → q2-1-data-exploration → Tables tab')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_025621-9wewrqaq</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9wewrqaq' target="_blank">q2-1-data-exploration</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9wewrqaq' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9wewrqaq</a>
# /tmp/ipython-input-3660775820.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels([fashion_cls[i] for i in unique], rotation=45, ha='right')
#  View run <strong style="color:#cdcd00">q2-1-data-exploration</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9wewrqaq' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9wewrqaq</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 2 media file(s), 52 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_025621-9wewrqaq/logs</code>
# ✓ Q2.1 Done! W&B project → Runs → q2-1-data-exploration → Tables tab

# %% [markdown]
# ---
# # Q2.2 — Hyperparameter Sweep (6 Marks) — 100+ runs
# **What to do:** Run 100+ configurations. In W&B, look at Parallel Coordinates plot to find which hyperparameter matters most.

# %%
sweep_config = {
    'method': 'bayes',  # Bayesian is smarter than random — finds good configs faster
    'metric': {'name': 'val_accuracy', 'goal': 'maximize'},
    'parameters': {
        'learning_rate': {'values': [0.001, 0.0005, 0.0001, 0.005, 0.01]},
        'optimizer':     {'values': ['adam', 'nadam', 'rmsprop', 'momentum', 'sgd', 'nag']},
        'activation':    {'values': ['relu', 'tanh', 'sigmoid']},
        'num_layers':    {'values': [2, 3, 4]},
        'hidden_size':   {'values': [32, 64, 128]},
        'batch_size':    {'values': [32, 64, 128]},
        'weight_init':   {'values': ['xavier', 'random']},
        'weight_decay':  {'values': [0.0, 0.0001, 0.0005]},
    }
}

def sweep_run():
    run = wandb.init()
    cfg = wandb.config
    model, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes   = [cfg.hidden_size] * cfg.num_layers,
        activation     = cfg.activation,
        optimizer_name = cfg.optimizer,
        learning_rate  = cfg.learning_rate,
        weight_init    = cfg.weight_init,
        loss_name      = 'cross_entropy',
        epochs         = 10,
        batch_size     = cfg.batch_size,
        weight_decay   = cfg.weight_decay,
        use_wandb      = True
    )
    wandb.finish()

sweep_id = wandb.sweep(sweep_config, project=WANDB_PROJECT)
print(f'Sweep ID: {sweep_id}')
print('Starting 100 runs... (this takes ~1-2 hours on Colab GPU)')
print('You can watch progress live at: https://wandb.ai')

wandb.agent(sweep_id, function=sweep_run, count=100)
# Out:
# Create sweep with ID: nzpuk5ui
# Sweep URL: https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui
# Sweep ID: nzpuk5ui
# Starting 100 runs... (this takes ~1-2 hours on Colab GPU)
# You can watch progress live at: https://wandb.ai
# wandb: Agent Starting Run: ykap16ty with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 2
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_110710-ykap16ty</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ykap16ty' target="_blank">volcanic-sweep-1</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ykap16ty' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ykap16ty</a>
#   Ep   1 | loss=0.7150 | val_acc=0.8998
#   Ep   5 | loss=0.2111 | val_acc=0.9363
#   Ep  10 | loss=0.1408 | val_acc=0.9542
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.96202</td></tr><tr><td>train_loss</td><td>0.14077</td></tr><tr><td>val_accuracy</td><td>0.95417</td></tr><tr><td>val_loss</td><td>0.16767</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">volcanic-sweep-1</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ykap16ty' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ykap16ty</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_110710-ykap16ty/logs</code>
# wandb: Agent Starting Run: 41dxu5zc with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	num_layers: 3
# wandb: 	optimizer: nag
# wandb: 	weight_decay: 0.0001
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_110748-41dxu5zc</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/41dxu5zc' target="_blank">legendary-sweep-2</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/41dxu5zc' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/41dxu5zc</a>
#   Ep   1 | loss=2.2762 | val_acc=0.1893
#   Ep   5 | loss=1.8900 | val_acc=0.5555
#   Ep  10 | loss=0.9270 | val_acc=0.7688
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▂▃▄▆▆▇▇██</td></tr><tr><td>train_loss</td><td>██▇▇▆▅▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▄▅▆▇▇██</td></tr><tr><td>val_loss</td><td>██▇▇▆▅▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.77224</td></tr><tr><td>train_loss</td><td>0.92704</td></tr><tr><td>val_accuracy</td><td>0.76883</td></tr><tr><td>val_loss</td><td>0.87974</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">legendary-sweep-2</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/41dxu5zc' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/41dxu5zc</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_110748-41dxu5zc/logs</code>
# wandb: Agent Starting Run: y1h0neth with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.005
# wandb: 	num_layers: 4
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_110818-y1h0neth</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/y1h0neth' target="_blank">eternal-sweep-3</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/y1h0neth' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/y1h0neth</a>
#   Ep   1 | loss=1.5370 | val_acc=0.8083
#   Ep   5 | loss=0.2884 | val_acc=0.9193
#   Ep  10 | loss=0.2018 | val_acc=0.9398
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.94383</td></tr><tr><td>train_loss</td><td>0.20176</td></tr><tr><td>val_accuracy</td><td>0.93983</td></tr><tr><td>val_loss</td><td>0.21752</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eternal-sweep-3</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/y1h0neth' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/y1h0neth</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_110818-y1h0neth/logs</code>
# wandb: Agent Starting Run: g9jg3qcp with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_layers: 2
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_110916-g9jg3qcp</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/g9jg3qcp' target="_blank">bright-sweep-4</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/g9jg3qcp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/g9jg3qcp</a>
#   Ep   1 | loss=2.3025 | val_acc=0.1353
#   Ep   5 | loss=2.3022 | val_acc=0.1123
#   Ep  10 | loss=2.3020 | val_acc=0.1123
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▆▅▅▄▃▂▂▁</td></tr><tr><td>val_accuracy</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▆▆▅▄▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.11237</td></tr><tr><td>train_loss</td><td>2.30196</td></tr><tr><td>val_accuracy</td><td>0.11233</td></tr><tr><td>val_loss</td><td>2.30192</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bright-sweep-4</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/g9jg3qcp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/g9jg3qcp</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_110916-g9jg3qcp/logs</code>
# wandb: Agent Starting Run: orh55w8i with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.0005
# wandb: 	num_layers: 4
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111011-orh55w8i</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/orh55w8i' target="_blank">crisp-sweep-5</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/orh55w8i' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/orh55w8i</a>
#   Ep   1 | loss=2.3024 | val_acc=0.0987
#   Ep   5 | loss=2.3012 | val_acc=0.1123
#   Ep  10 | loss=2.3012 | val_acc=0.1123
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁█████████</td></tr><tr><td>train_loss</td><td>█▄▃▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁█████████</td></tr><tr><td>val_loss</td><td>█▄▃▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.11237</td></tr><tr><td>train_loss</td><td>2.30119</td></tr><tr><td>val_accuracy</td><td>0.11233</td></tr><tr><td>val_loss</td><td>2.30116</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-sweep-5</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/orh55w8i' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/orh55w8i</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111011-orh55w8i/logs</code>
# wandb: Agent Starting Run: 3dpnduty with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.005
# wandb: 	num_layers: 4
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111052-3dpnduty</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/3dpnduty' target="_blank">confused-sweep-6</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/3dpnduty' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/3dpnduty</a>
#   Ep   1 | loss=2.3016 | val_acc=0.1123
#   Ep   5 | loss=2.3016 | val_acc=0.1123
#   Ep  10 | loss=2.3016 | val_acc=0.1123
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▃▇▃▅▃▁▃▇</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▂▄▅█▁▄▆▇▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.11237</td></tr><tr><td>train_loss</td><td>2.30163</td></tr><tr><td>val_accuracy</td><td>0.11233</td></tr><tr><td>val_loss</td><td>2.30141</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">confused-sweep-6</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/3dpnduty' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/3dpnduty</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111052-3dpnduty/logs</code>
# wandb: Agent Starting Run: l0g5hbwz with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	num_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0001
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111139-l0g5hbwz</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/l0g5hbwz' target="_blank">ethereal-sweep-7</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/l0g5hbwz' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/l0g5hbwz</a>
#   Ep   1 | loss=0.5885 | val_acc=0.9135
#   Ep   5 | loss=0.1667 | val_acc=0.9407
#   Ep  10 | loss=0.1456 | val_acc=0.9533
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▂▆▆▆▇▅█▆█</td></tr><tr><td>train_loss</td><td>█▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▇▆▅█▅█▆▇</td></tr><tr><td>val_loss</td><td>█▇▁▃▄▁▄▁▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.96498</td></tr><tr><td>train_loss</td><td>0.14557</td></tr><tr><td>val_accuracy</td><td>0.95333</td></tr><tr><td>val_loss</td><td>0.18268</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-7</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/l0g5hbwz' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/l0g5hbwz</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111139-l0g5hbwz/logs</code>
# wandb: Agent Starting Run: 6gzyy21h with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 4
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111159-6gzyy21h</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6gzyy21h' target="_blank">firm-sweep-8</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6gzyy21h' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6gzyy21h</a>
#   Ep   1 | loss=0.3876 | val_acc=0.9360
#   Ep   5 | loss=0.0718 | val_acc=0.9627
#   Ep  10 | loss=0.0342 | val_acc=0.9725
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▆▇▇███</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▆███▇█</td></tr><tr><td>val_loss</td><td>█▄▂▂▂▁▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99022</td></tr><tr><td>train_loss</td><td>0.0342</td></tr><tr><td>val_accuracy</td><td>0.9725</td></tr><tr><td>val_loss</td><td>0.12281</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">firm-sweep-8</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6gzyy21h' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6gzyy21h</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111159-6gzyy21h/logs</code>
# wandb: Agent Starting Run: gqcxhjyp with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	hidden_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 2
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0001
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111236-gqcxhjyp</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/gqcxhjyp' target="_blank">rose-sweep-9</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/gqcxhjyp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/gqcxhjyp</a>
#   Ep   1 | loss=0.3968 | val_acc=0.9235
#   Ep   5 | loss=0.1270 | val_acc=0.9555
#   Ep  10 | loss=0.0842 | val_acc=0.9612
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▄▄▃▂▃▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.978</td></tr><tr><td>train_loss</td><td>0.08421</td></tr><tr><td>val_accuracy</td><td>0.96117</td></tr><tr><td>val_loss</td><td>0.13596</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rose-sweep-9</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/gqcxhjyp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/gqcxhjyp</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111236-gqcxhjyp/logs</code>
# wandb: Agent Starting Run: b0sko1te with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111257-b0sko1te</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/b0sko1te' target="_blank">peachy-sweep-10</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/b0sko1te' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/b0sko1te</a>
#   Ep   1 | loss=0.7772 | val_acc=0.9027
#   Ep   5 | loss=0.1163 | val_acc=0.9562
#   Ep  10 | loss=0.0779 | val_acc=0.9672
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▇█████</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇█████</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.98087</td></tr><tr><td>train_loss</td><td>0.07788</td></tr><tr><td>val_accuracy</td><td>0.96717</td></tr><tr><td>val_loss</td><td>0.11194</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peachy-sweep-10</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/b0sko1te' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/b0sko1te</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111257-b0sko1te/logs</code>
# wandb: Agent Starting Run: iieybks3 with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 32
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.0005
# wandb: 	num_layers: 2
# wandb: 	optimizer: nag
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111354-iieybks3</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/iieybks3' target="_blank">zany-sweep-11</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/iieybks3' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/iieybks3</a>
#   Ep   1 | loss=2.2986 | val_acc=0.1142
#   Ep   5 | loss=0.6335 | val_acc=0.8347
#   Ep  10 | loss=0.3761 | val_acc=0.8968
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▆▇▇█████</td></tr><tr><td>train_loss</td><td>██▅▃▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▆▇▇█████</td></tr><tr><td>val_loss</td><td>█▇▄▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.89661</td></tr><tr><td>train_loss</td><td>0.37607</td></tr><tr><td>val_accuracy</td><td>0.89683</td></tr><tr><td>val_loss</td><td>0.37428</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zany-sweep-11</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/iieybks3' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/iieybks3</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111354-iieybks3/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: w0ui86xp with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	num_layers: 2
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111536-w0ui86xp</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/w0ui86xp' target="_blank">grateful-sweep-12</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/w0ui86xp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/w0ui86xp</a>
#   Ep   1 | loss=2.3025 | val_acc=0.1123
#   Ep   5 | loss=2.3021 | val_acc=0.1123
#   Ep  10 | loss=2.3018 | val_acc=0.1123
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▆▅▄▃▃▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▃▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.11237</td></tr><tr><td>train_loss</td><td>2.30176</td></tr><tr><td>val_accuracy</td><td>0.11233</td></tr><tr><td>val_loss</td><td>2.30172</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grateful-sweep-12</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/w0ui86xp' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/w0ui86xp</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111536-w0ui86xp/logs</code>
# wandb: Agent Starting Run: 2qh4tg1q with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 2
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111557-2qh4tg1q</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/2qh4tg1q' target="_blank">woven-sweep-13</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/2qh4tg1q' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/2qh4tg1q</a>
#   Ep   1 | loss=1.4203 | val_acc=0.8335
#   Ep   5 | loss=0.3294 | val_acc=0.9090
#   Ep  10 | loss=0.2551 | val_acc=0.9272
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.92894</td></tr><tr><td>train_loss</td><td>0.25515</td></tr><tr><td>val_accuracy</td><td>0.92717</td></tr><tr><td>val_loss</td><td>0.26303</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">woven-sweep-13</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/2qh4tg1q' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/2qh4tg1q</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111557-2qh4tg1q/logs</code>
# wandb: Agent Starting Run: duz72ekd with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	hidden_size: 32
# wandb: 	learning_rate: 0.005
# wandb: 	num_layers: 2
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0001
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111639-duz72ekd</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/duz72ekd' target="_blank">olive-sweep-14</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/duz72ekd' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/duz72ekd</a>
#   Ep   1 | loss=2.2969 | val_acc=0.3367
#   Ep   5 | loss=1.6518 | val_acc=0.6088
#   Ep  10 | loss=0.8747 | val_acc=0.7885
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▂▄▄▅▆▇▇██</td></tr><tr><td>train_loss</td><td>██▇▆▅▄▃▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▄▅▆▇▇██</td></tr><tr><td>val_loss</td><td>██▇▆▄▃▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.7872</td></tr><tr><td>train_loss</td><td>0.87469</td></tr><tr><td>val_accuracy</td><td>0.7885</td></tr><tr><td>val_loss</td><td>0.83939</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">olive-sweep-14</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/duz72ekd' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/duz72ekd</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_111639-duz72ekd/logs</code>
# wandb: Agent Starting Run: zo2caxxa with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_layers: 4
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0.0001
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_111710-zo2caxxa</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zo2caxxa' target="_blank">swept-sweep-15</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zo2caxxa' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zo2caxxa</a>
#   Ep   1 | loss=1.3387 | val_acc=0.5998
#   Ep   5 | loss=0.4748 | val_acc=0.8733
#   Ep  10 | loss=0.2370 | val_acc=0.9337
# ...
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_125836-1tlq37vw</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/1tlq37vw' target="_blank">clean-sweep-96</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/1tlq37vw' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/1tlq37vw</a>
#   Ep   1 | loss=0.6830 | val_acc=0.9210
#   Ep   5 | loss=0.1045 | val_acc=0.9610
#   Ep  10 | loss=0.0575 | val_acc=0.9693
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.98406</td></tr><tr><td>train_loss</td><td>0.0575</td></tr><tr><td>val_accuracy</td><td>0.96933</td></tr><tr><td>val_loss</td><td>0.10463</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">clean-sweep-96</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/1tlq37vw' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/1tlq37vw</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_125836-1tlq37vw/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ul383vae with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.01
# wandb: 	num_layers: 4
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_125933-ul383vae</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ul383vae' target="_blank">vivid-sweep-97</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ul383vae' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ul383vae</a>
#   Ep   1 | loss=0.3470 | val_acc=0.9367
#   Ep   5 | loss=0.0868 | val_acc=0.9682
#   Ep  10 | loss=0.0476 | val_acc=0.9675
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▇▆▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇▆███▇</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.9867</td></tr><tr><td>train_loss</td><td>0.04763</td></tr><tr><td>val_accuracy</td><td>0.9675</td></tr><tr><td>val_loss</td><td>0.1059</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivid-sweep-97</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ul383vae' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/ul383vae</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_125933-ul383vae/logs</code>
# wandb: Agent Starting Run: fkzhvwk5 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_130126-fkzhvwk5</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/fkzhvwk5' target="_blank">dauntless-sweep-98</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/fkzhvwk5' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/fkzhvwk5</a>
#   Ep   1 | loss=0.9896 | val_acc=0.8460
#   Ep   5 | loss=0.1220 | val_acc=0.9567
#   Ep  10 | loss=0.0620 | val_acc=0.9643
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇█████</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▇▇▇█▇█</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.98072</td></tr><tr><td>train_loss</td><td>0.062</td></tr><tr><td>val_accuracy</td><td>0.96433</td></tr><tr><td>val_loss</td><td>0.12529</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-sweep-98</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/fkzhvwk5' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/fkzhvwk5</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_130126-fkzhvwk5/logs</code>
# wandb: Agent Starting Run: 9ek7imre with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.01
# wandb: 	num_layers: 4
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_130213-9ek7imre</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9ek7imre' target="_blank">fallen-sweep-99</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9ek7imre' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9ek7imre</a>
#   Ep   1 | loss=0.5511 | val_acc=0.9310
#   Ep   5 | loss=0.0875 | val_acc=0.9678
#   Ep  10 | loss=0.0426 | val_acc=0.9717
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▇█████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.98928</td></tr><tr><td>train_loss</td><td>0.0426</td></tr><tr><td>val_accuracy</td><td>0.97167</td></tr><tr><td>val_loss</td><td>0.10195</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fallen-sweep-99</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9ek7imre' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/9ek7imre</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_130213-9ek7imre/logs</code>
# wandb: Agent Starting Run: t7v8j0xt with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 128
# wandb: 	hidden_size: 128
# wandb: 	learning_rate: 0.01
# wandb: 	num_layers: 4
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260222_130259-t7v8j0xt</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/t7v8j0xt' target="_blank">sparkling-sweep-100</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View sweep at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/sweeps/nzpuk5ui</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/t7v8j0xt' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/t7v8j0xt</a>
#   Ep   1 | loss=0.4330 | val_acc=0.9212
#   Ep   5 | loss=0.1117 | val_acc=0.9605
#   Ep  10 | loss=0.0633 | val_acc=0.9700
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▆▇▇███</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.9848</td></tr><tr><td>train_loss</td><td>0.06334</td></tr><tr><td>val_accuracy</td><td>0.97</td></tr><tr><td>val_loss</td><td>0.10022</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sparkling-sweep-100</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/t7v8j0xt' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/t7v8j0xt</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_130259-t7v8j0xt/logs</code>

# %% [markdown]
# ### After sweep finishes:
# 1. Go to **wandb.ai → your project → Sweeps**
# 2. Click on the sweep → **Parallel Coordinates** tab
# 3. Screenshot this — it shows which hyperparameter most impacts accuracy
# 4. Put this screenshot + your analysis in your W&B Report

# %% [markdown]
# ---
# # Q2.3 — Optimizer Showdown (5 Marks)
# **What to do:** Compare all 6 optimizers on same 3L-128-ReLU architecture.

# %%
OPTS = ['sgd', 'momentum', 'nag', 'rmsprop', 'adam', 'nadam']
# Adam/Nadam/RMSProp need lower LR; SGD/Momentum/NAG use higher LR
OPT_LR = {'sgd': 0.01, 'momentum': 0.01, 'nag': 0.01,
           'rmsprop': 0.001, 'adam': 0.001, 'nadam': 0.001}

opt_histories = {}

for opt_name in OPTS:
    print(f'\nTraining with {opt_name.upper()}...')
    run = wandb.init(
        project=WANDB_PROJECT,
        name=f'q2-3-{opt_name}',
        config={'optimizer': opt_name, 'lr': OPT_LR[opt_name]}
    )
    model, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes=[128, 128, 128], activation='relu',
        optimizer_name=opt_name, learning_rate=OPT_LR[opt_name],
        epochs=10, batch_size=64, use_wandb=True
    )
    opt_histories[opt_name] = hist
    wandb.finish()

#plot comparison
colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#a65628']
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for i, (opt, hist) in enumerate(opt_histories.items()):
    ep = range(1, len(hist['train_loss'])+1)
    axes[0].plot(ep, hist['train_loss'], label=opt.upper(), color=colors[i], lw=2)
    axes[1].plot(ep, hist['val_acc'],   label=opt.upper(), color=colors[i], lw=2)

for ax, title, ylabel in zip(axes,
    ['Training Loss: All Optimizers', 'Validation Accuracy: All Optimizers'],
    ['Loss', 'Accuracy']):
    ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
    ax.set_title(title, fontsize=12); ax.legend(); ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('optimizer_comparison.png', dpi=120)
plt.show()

run = wandb.init(project=WANDB_PROJECT, entity=WANDB_ENTITY, name='q2-3-comparison-plot')
wandb.log({'optimizer_comparison_plot': wandb.Image('optimizer_comparison.png')})
wandb.finish()

#show which optimizer had lowest loss in first 5 epochs
print('\nLoss after 5 epochs:')
for opt, hist in opt_histories.items():
    print(f'  {opt:10s}: {hist["train_loss"][4]:.4f}')
# Out:
# Training with SGD...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_025659-42iabc5e</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/42iabc5e' target="_blank">q2-3-sgd</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/42iabc5e' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/42iabc5e</a>
#   Ep   1 | loss=0.9678 | val_acc=0.8752
#   Ep   5 | loss=0.2344 | val_acc=0.9317
#   Ep  10 | loss=0.1532 | val_acc=0.9520
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▆▇▇███</td></tr><tr><td>val_loss</td><td>█▅▄▄▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.95772</td></tr><tr><td>train_loss</td><td>0.15317</td></tr><tr><td>val_accuracy</td><td>0.952</td></tr><tr><td>val_loss</td><td>0.17163</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-sgd</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/42iabc5e' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/42iabc5e</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_025659-42iabc5e/logs</code>
# Training with MOMENTUM...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_025744-7ib4c4ym</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/7ib4c4ym' target="_blank">q2-3-momentum</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/7ib4c4ym' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/7ib4c4ym</a>
#   Ep   1 | loss=0.3850 | val_acc=0.9422
#   Ep   5 | loss=0.0628 | val_acc=0.9688
#   Ep  10 | loss=0.0243 | val_acc=0.9760
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▆▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▇▇▇▇▇█</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99396</td></tr><tr><td>train_loss</td><td>0.0243</td></tr><tr><td>val_accuracy</td><td>0.976</td></tr><tr><td>val_loss</td><td>0.10107</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-momentum</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/7ib4c4ym' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/7ib4c4ym</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_025744-7ib4c4ym/logs</code>
# Training with NAG...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_025832-818sng5v</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/818sng5v' target="_blank">q2-3-nag</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/818sng5v' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/818sng5v</a>
#   Ep   1 | loss=0.3611 | val_acc=0.9467
#   Ep   5 | loss=0.0602 | val_acc=0.9712
#   Ep  10 | loss=0.0213 | val_acc=0.9767
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▇▇███</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇█▇███</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99554</td></tr><tr><td>train_loss</td><td>0.02133</td></tr><tr><td>val_accuracy</td><td>0.97667</td></tr><tr><td>val_loss</td><td>0.08959</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-nag</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/818sng5v' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/818sng5v</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_025832-818sng5v/logs</code>
# Training with RMSPROP...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_025923-zmgrpsh4</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zmgrpsh4' target="_blank">q2-3-rmsprop</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zmgrpsh4' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zmgrpsh4</a>
#   Ep   1 | loss=0.2634 | val_acc=0.9543
#   Ep   5 | loss=0.0503 | val_acc=0.9710
#   Ep  10 | loss=0.0235 | val_acc=0.9720
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇▇▇████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇▆▇██▇▆</td></tr><tr><td>val_loss</td><td>█▃▁▁▂▂▁▃▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99359</td></tr><tr><td>train_loss</td><td>0.02345</td></tr><tr><td>val_accuracy</td><td>0.972</td></tr><tr><td>val_loss</td><td>0.1637</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-rmsprop</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zmgrpsh4' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/zmgrpsh4</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_025923-zmgrpsh4/logs</code>
# Training with ADAM...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030014-cb4kg57x</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/cb4kg57x' target="_blank">q2-3-adam</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/cb4kg57x' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/cb4kg57x</a>
#   Ep   1 | loss=0.2667 | val_acc=0.9515
#   Ep   5 | loss=0.0443 | val_acc=0.9732
#   Ep  10 | loss=0.0189 | val_acc=0.9790
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇▇▇▆▇█</td></tr><tr><td>val_loss</td><td>█▃▂▂▁▂▁▃▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99567</td></tr><tr><td>train_loss</td><td>0.01885</td></tr><tr><td>val_accuracy</td><td>0.979</td></tr><tr><td>val_loss</td><td>0.10254</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-adam</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/cb4kg57x' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/cb4kg57x</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030014-cb4kg57x/logs</code>
# Training with NADAM...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030113-sjc3yrhv</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/sjc3yrhv' target="_blank">q2-3-nadam</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/sjc3yrhv' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/sjc3yrhv</a>
#   Ep   1 | loss=0.2533 | val_acc=0.9613
#   Ep   5 | loss=0.0411 | val_acc=0.9773
#   Ep  10 | loss=0.0202 | val_acc=0.9765
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▅▅▇▇▆█▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▅█▇▆▇▆█</td></tr><tr><td>val_loss</td><td>█▅▃▃▁▂▅▄▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_accuracy</td><td>0.99663</td></tr><tr><td>train_loss</td><td>0.02015</td></tr><tr><td>val_accuracy</td><td>0.9765</td></tr><tr><td>val_loss</td><td>0.1006</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-3-nadam</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/sjc3yrhv' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/sjc3yrhv</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030113-sjc3yrhv/logs</code>
# Loss after 5 epochs:
#   sgd       : 0.2344
#   momentum  : 0.0628
#   nag       : 0.0602
#   rmsprop   : 0.0503
#   adam      : 0.0443
#   nadam     : 0.0411

# %% [markdown]
# ---
# # Q2.4 — Vanishing Gradient Analysis (5 Marks)
# **What to do:** Compare gradient norms in first layer: Sigmoid vs ReLU with Adam on deep network.

# %%
for act_name in ['sigmoid', 'relu']:
    print(f'\n--- {act_name.upper()} (5 hidden layers) ---')
    run = wandb.init(
        project=WANDB_PROJECT,
        name=f'q2-4-vanishing-{act_name}',
        config={'activation': act_name, 'num_layers': 5, 'optimizer': 'adam'}
    )
    model, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes   = [128]*5,    #DEEP network (5 layers) = more vanishing
        activation     = act_name,
        optimizer_name = 'adam',
        learning_rate  = 0.001,
        epochs         = 10,
        batch_size     = 64,
        log_grad_norms = True,       #KEY: logs layer_1_grad_norm, layer_2_grad_norm
        use_wandb      = True
    )
    wandb.finish()

print('\n✓ Q2.4 Done!')
# Out:
# --- SIGMOID (5 hidden layers) ---
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030417-bge33wuk</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/bge33wuk' target="_blank">q2-4-vanishing-sigmoid</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/bge33wuk' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/bge33wuk</a>
#   Ep   1 | loss=0.8745 | val_acc=0.9053
#   Ep   5 | loss=0.1184 | val_acc=0.9588
#   Ep  10 | loss=0.0521 | val_acc=0.9685
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>layer_1_grad_norm</td><td>▅▄▄▃▆█▅▆▁█</td></tr><tr><td>layer_2_grad_norm</td><td>▆▃▃▂▇█▅▅▁█</td></tr><tr><td>layer_3_grad_norm</td><td>█▃▃▃▇▆▄▄▁▇</td></tr><tr><td>layer_4_grad_norm</td><td>█▄▃▃▆▆▄▄▁▇</td></tr><tr><td>layer_5_grad_norm</td><td>█▄▄▄▇▆▄▄▁▅</td></tr><tr><td>layer_6_grad_norm</td><td>█▃▅▄▆▅▃▄▁▅</td></tr><tr><td>train_accuracy</td><td>▁▄▆▆▇▇█▇██</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇▇▇████</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>layer_1_grad_norm</td><td>0.58971</td></tr><tr><td>layer_2_grad_norm</td><td>0.48455</td></tr><tr><td>layer_3_grad_norm</td><td>0.1974</td></tr><tr><td>layer_4_grad_norm</td><td>0.13901</td></tr><tr><td>layer_5_grad_norm</td><td>0.11617</td></tr><tr><td>layer_6_grad_norm</td><td>0.28819</td></tr><tr><td>train_accuracy</td><td>0.98893</td></tr><tr><td>train_loss</td><td>0.05208</td></tr><tr><td>val_accuracy</td><td>0.9685</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-4-vanishing-sigmoid</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/bge33wuk' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/bge33wuk</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030417-bge33wuk/logs</code>
# --- RELU (5 hidden layers) ---
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030557-6sff9h0j</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6sff9h0j' target="_blank">q2-4-vanishing-relu</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6sff9h0j' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6sff9h0j</a>
#   Ep   1 | loss=0.2821 | val_acc=0.9477
#   Ep   5 | loss=0.0574 | val_acc=0.9688
#   Ep  10 | loss=0.0304 | val_acc=0.9738
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>layer_1_grad_norm</td><td>▇▂▂▇█▅▂▁▅▂</td></tr><tr><td>layer_2_grad_norm</td><td>▆▂▂▆█▅▃▁▅▂</td></tr><tr><td>layer_3_grad_norm</td><td>█▂▂▅▇▄▃▁▄▂</td></tr><tr><td>layer_4_grad_norm</td><td>█▂▂▄▆▃▃▁▃▂</td></tr><tr><td>layer_5_grad_norm</td><td>█▂▂▃▆▂▂▁▂▂</td></tr><tr><td>layer_6_grad_norm</td><td>█▂▂▄▆▃▂▁▂▂</td></tr><tr><td>train_accuracy</td><td>▁▃▅▇▆▆▆█▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▆▆▆█▆▇</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>layer_1_grad_norm</td><td>0.3418</td></tr><tr><td>layer_2_grad_norm</td><td>0.232</td></tr><tr><td>layer_3_grad_norm</td><td>0.14477</td></tr><tr><td>layer_4_grad_norm</td><td>0.08811</td></tr><tr><td>layer_5_grad_norm</td><td>0.07243</td></tr><tr><td>layer_6_grad_norm</td><td>0.10414</td></tr><tr><td>train_accuracy</td><td>0.99448</td></tr><tr><td>train_loss</td><td>0.03041</td></tr><tr><td>val_accuracy</td><td>0.97383</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-4-vanishing-relu</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6sff9h0j' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/6sff9h0j</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030557-6sff9h0j/logs</code>
# ✓ Q2.4 Done!

# %% [markdown]
# ---
# # Q2.5 — Dead Neuron Investigation (6 Marks)
# **What to do:** High LR + ReLU + SGD → dead neurons. Compare with Tanh.

# %%
for act_name in ['relu', 'tanh']:
    print(f'\n--- {act_name.upper()} with HIGH LR=0.1 ---')
    run = wandb.init(
        project=WANDB_PROJECT,
        name=f'q2-5-dead-neuron-{act_name}-lr0.1',
        config={'activation': act_name, 'lr': 0.1, 'optimizer': 'sgd'}
    )
    model, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes   = [128, 128, 128],
        activation     = act_name,
        optimizer_name = 'sgd',
        learning_rate  = 0.1,        #HIGH LR → kills ReLU neurons
        epochs         = 15,
        batch_size     = 64,
        log_activations = True,      #KEY: logs dead neuron fractions
        use_wandb       = True
    )

    #activation distribution plot
    _ = model.forward(X_val[:500])
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    for li in range(3):
        layer = model.layers[li]
        flat  = layer.a.flatten()
        dead  = np.mean(flat == 0) * 100
        axes[li].hist(flat, bins=60, color='steelblue', alpha=0.8, edgecolor='white')
        axes[li].set_title(f'Layer {li+1}\nDead neurons: {dead:.1f}%')
        axes[li].set_xlabel('Activation value')
    plt.suptitle(f'{act_name.upper()} — LR=0.1', fontsize=13)
    plt.tight_layout()
    plt.savefig(f'dead_neuron_{act_name}.png', dpi=100)
    wandb.log({'activation_distribution': wandb.Image(f'dead_neuron_{act_name}.png')})
    plt.show()
    wandb.finish()

print('✓ Q2.5 Done! ')
# Out:
# --- RELU with HIGH LR=0.1 ---
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030727-nc00hhdq</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nc00hhdq' target="_blank">q2-5-dead-neuron-relu-lr0.1</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nc00hhdq' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nc00hhdq</a>
#   Ep   1 | loss=0.3765 | val_acc=0.9420
#   Ep   5 | loss=0.0613 | val_acc=0.9710
#   Ep  10 | loss=0.0235 | val_acc=0.9693
#   Ep  15 | loss=0.0062 | val_acc=0.9773
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>layer_1_act_mean</td><td>▂▁▁▂▃▁▄▂▄▅▅▆█▇█</td></tr><tr><td>layer_1_dead_frac</td><td>▁▄▅▆▆█▇██▇█▇▇▇▇</td></tr><tr><td>layer_2_act_mean</td><td>▁▁▁▂▂▂▃▃▄▅▅▆▇▇█</td></tr><tr><td>layer_2_dead_frac</td><td>▁▁▅▅▇███▇█▇▇▇▇▅</td></tr><tr><td>layer_3_act_mean</td><td>▁▂▂▃▃▃▄▄▅▅▅▆▇▇█</td></tr><tr><td>layer_3_dead_frac</td><td>▆▃▄▅▆█▆█▇▄▄▃▃▃▁</td></tr><tr><td>train_accuracy</td><td>▁▃▅▆▆▅▆▇▇▇▇█▇██</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇▇▆▇██▆█▇▇██</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>layer_1_act_mean</td><td>0.3671</td></tr><tr><td>layer_1_dead_frac</td><td>0.57151</td></tr><tr><td>layer_2_act_mean</td><td>0.52399</td></tr><tr><td>layer_2_dead_frac</td><td>0.46881</td></tr><tr><td>layer_3_act_mean</td><td>0.91806</td></tr><tr><td>layer_3_dead_frac</td><td>0.41612</td></tr><tr><td>train_accuracy</td><td>0.99961</td></tr><tr><td>train_loss</td><td>0.00618</td></tr><tr><td>val_accuracy</td><td>0.97733</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-5-dead-neuron-relu-lr0.1</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nc00hhdq' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nc00hhdq</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030727-nc00hhdq/logs</code>
# --- TANH with HIGH LR=0.1 ---
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_030903-su6nvocy</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/su6nvocy' target="_blank">q2-5-dead-neuron-tanh-lr0.1</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/su6nvocy' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/su6nvocy</a>
#   Ep   1 | loss=0.3488 | val_acc=0.9218
#   Ep   5 | loss=0.0839 | val_acc=0.9692
#   Ep  10 | loss=0.0358 | val_acc=0.9722
#   Ep  15 | loss=0.0144 | val_acc=0.9753
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>layer_1_act_mean</td><td>▁▃▅▅▆▆▇▇▇▇▇████</td></tr><tr><td>layer_1_dead_frac</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>layer_2_act_mean</td><td>▁▃▄▅▆▆▆▇▇▇▇████</td></tr><tr><td>layer_2_dead_frac</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>layer_3_act_mean</td><td>▁▃▄▄▅▆▆▆▇▇▇▇███</td></tr><tr><td>layer_3_dead_frac</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▇▆▇▇▇███▇█</td></tr><tr><td>train_loss</td><td>█▄▃▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇▇▆█▇▇███▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>layer_1_act_mean</td><td>0.6104</td></tr><tr><td>layer_1_dead_frac</td><td>0</td></tr><tr><td>layer_2_act_mean</td><td>0.60908</td></tr><tr><td>layer_2_dead_frac</td><td>0</td></tr><tr><td>layer_3_act_mean</td><td>0.62138</td></tr><tr><td>layer_3_dead_frac</td><td>0</td></tr><tr><td>train_accuracy</td><td>0.99804</td></tr><tr><td>train_loss</td><td>0.01442</td></tr><tr><td>val_accuracy</td><td>0.97533</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-5-dead-neuron-tanh-lr0.1</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/su6nvocy' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/su6nvocy</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_030903-su6nvocy/logs</code>
# ✓ Q2.5 Done!

# %% [markdown]
# ---
# # Q2.6 — Loss Function Comparison (4 Marks)

# %%
loss_histories = {}

for loss_name in ['cross_entropy', 'mse']:
    print(f'\nTraining with {loss_name}...')
    run = wandb.init(
        project=WANDB_PROJECT,
        name=f'q2-6-loss-{loss_name}',
        config={'loss': loss_name}
    )
    model, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes=[128,128,128], activation='relu',
        optimizer_name='adam', learning_rate=0.001,
        loss_name=loss_name, epochs=15, batch_size=64, use_wandb=True
    )
    loss_histories[loss_name] = hist
    wandb.finish()

# Plot
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for lname, hist in loss_histories.items():
    ep = range(1, len(hist['train_loss'])+1)
    axes[0].plot(ep, hist['train_loss'], label=lname, lw=2)
    axes[1].plot(ep, hist['val_acc'],   label=lname, lw=2)
for ax, t, y in zip(axes, ['Training Loss', 'Validation Accuracy'], ['Loss','Accuracy']):
    ax.set_title(f'{t}: CE vs MSE'); ax.legend(); ax.set_xlabel('Epoch')
    ax.set_ylabel(y); ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('loss_comparison.png', dpi=120)
plt.show()
print('✓ Q2.6 Done!')
# Out:
# Training with cross_entropy...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_031148-nth07zk7</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nth07zk7' target="_blank">q2-6-loss-cross_entropy</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nth07zk7' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nth07zk7</a>
#   Ep   1 | loss=0.2651 | val_acc=0.9575
#   Ep   5 | loss=0.0431 | val_acc=0.9732
#   Ep  10 | loss=0.0210 | val_acc=0.9753
#   Ep  15 | loss=0.0161 | val_acc=0.9737
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▅▅▆▆▇▆█▇▇████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇█▇▇█▆▆██▇</td></tr><tr><td>val_loss</td><td>█▅▂▃▁▄▁▄▄▃▆▅▃▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_accuracy</td><td>0.99491</td></tr><tr><td>train_loss</td><td>0.01614</td></tr><tr><td>val_accuracy</td><td>0.97367</td></tr><tr><td>val_loss</td><td>0.12816</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-6-loss-cross_entropy</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nth07zk7' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/nth07zk7</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_031148-nth07zk7/logs</code>
# Training with mse...
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_031320-tu5d03tb</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/tu5d03tb' target="_blank">q2-6-loss-mse</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/tu5d03tb' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/tu5d03tb</a>
#   Ep   1 | loss=0.1267 | val_acc=0.9403
#   Ep   5 | loss=0.0333 | val_acc=0.9672
#   Ep  10 | loss=0.0199 | val_acc=0.9757
#   Ep  15 | loss=0.0153 | val_acc=0.9772
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▆▆▇▇█▇██████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▆▇▇█▇█▇▇▇▇█</td></tr><tr><td>val_loss</td><td>█▄▂▂▂▂▂▁▂▁▁▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_accuracy</td><td>0.99263</td></tr><tr><td>train_loss</td><td>0.01534</td></tr><tr><td>val_accuracy</td><td>0.97717</td></tr><tr><td>val_loss</td><td>0.03921</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-6-loss-mse</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/tu5d03tb' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/tu5d03tb</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_031320-tu5d03tb/logs</code>
# ✓ Q2.6 Done!

# %% [markdown]
# ---
# # Q2.7 — Global Performance Analysis (4 Marks)

# %%
#Global Performance: Train vs Val vs Test Accuracy
configs_q27 = [
    {'name':'adam-relu-3L-128',        'opt':'adam',  'lr':0.001, 'layers':3, 'sz':128, 'act':'relu',   'wd':0.0},
    {'name':'adam-relu-4L-128',        'opt':'adam',  'lr':0.001, 'layers':4, 'sz':128, 'act':'relu',   'wd':0.0},
    {'name':'sgd-tanh-3L-64',          'opt':'sgd',   'lr':0.01,  'layers':3, 'sz':64,  'act':'tanh',   'wd':0.0},
    {'name':'adam-relu-3L-highLR',     'opt':'adam',  'lr':0.01,  'layers':3, 'sz':128, 'act':'relu',   'wd':0.0},
    {'name':'nadam-tanh-3L-128-wd1e4', 'opt':'nadam', 'lr':0.001, 'layers':3, 'sz':128, 'act':'tanh',  'wd':0.0001},
    {'name':'sgd-sigmoid-2L-64',       'opt':'sgd',   'lr':0.01,  'layers':2, 'sz':64,  'act':'sigmoid','wd':0.0},
]

run = wandb.init(project=WANDB_PROJECT, entity=WANDB_ENTITY, name='q2-7-global-performance')

train_accs, val_accs, test_accs, run_names = [], [], [], []

for cfg in configs_q27:
    print(f"Config: {cfg['name']}")
    m, hist = build_and_train(
        X_tr, y_tr_oh, X_val, y_val_oh, y_val,
        hidden_sizes=[cfg['sz']]*cfg['layers'], activation=cfg['act'],
        optimizer_name=cfg['opt'], learning_rate=cfg['lr'],
        epochs=10, batch_size=64, weight_decay=cfg['wd'], use_wandb=False
    )
    train_acc = max(hist['train_acc'])
    val_acc   = max(hist['val_acc'])

    #Test accuracy on held-out test set
    test_preds = m.predict(X_te)
    test_acc   = float(np.mean(test_preds == y_te))

    train_accs.append(train_acc)
    val_accs.append(val_acc)
    test_accs.append(test_acc)
    run_names.append(cfg['name'])

    wandb.log({
        'config':      cfg['name'],
        'train_acc':   train_acc,
        'val_acc':     val_acc,
        'test_acc':    test_acc,
        'overfit_gap': train_acc - test_acc,
    })
    print(f"  train={train_acc:.4f} | val={val_acc:.4f} | test={test_acc:.4f}")

#Plot 1: Scatter train vs val
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

gap = [t - v for t, v in zip(train_accs, val_accs)]
colors_pt = ['red' if g > 0.05 else 'green' for g in gap]

for i in range(len(run_names)):
    axes[0].scatter(train_accs[i], val_accs[i], color=colors_pt[i], s=120, zorder=5)
    axes[0].annotate(run_names[i], (train_accs[i], val_accs[i]),
                     fontsize=7, xytext=(5, 5), textcoords='offset points')

lim = [min(train_accs + val_accs) - 0.02, 1.01]
axes[0].plot(lim, lim, 'k--', alpha=0.4, label='Perfect generalization line')
axes[0].set_xlabel('Train Accuracy', fontsize=12)
axes[0].set_ylabel('Val Accuracy', fontsize=12)
axes[0].set_title('Train vs Val Accuracy\n(Green = generalizes | Red = overfitting)', fontsize=11)
axes[0].legend()
axes[0].grid(alpha=0.3)

#Plot 2: Bar chart train vs val vs test
x = np.arange(len(run_names))
w = 0.25
axes[1].bar(x - w, train_accs, w, label='Train', color='steelblue')
axes[1].bar(x,     val_accs,   w, label='Val',   color='orange')
axes[1].bar(x + w, test_accs,  w, label='Test',  color='green')
axes[1].set_xticks(x)
axes[1].set_xticklabels(run_names, rotation=30, ha='right', fontsize=8)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Train vs Val vs Test Accuracy per Config', fontsize=11)
axes[1].legend()
axes[1].grid(alpha=0.3, axis='y')
axes[1].set_ylim(0, 1.05)

plt.tight_layout()
plt.savefig('global_perf.png', dpi=120)
wandb.log({'global_performance': wandb.Image('global_perf.png')})
plt.show()
wandb.finish()
print('✓ Q2.7 Done!')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_031452-qdsbva8n</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/qdsbva8n' target="_blank">q2-7-global-performance</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/qdsbva8n' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/qdsbva8n</a>
# Config: adam-relu-3L-128
#   Ep   1 | loss=0.2724 | val_acc=0.9552
#   Ep   5 | loss=0.0446 | val_acc=0.9735
#   Ep  10 | loss=0.0246 | val_acc=0.9762
#   train=0.9952 | val=0.9762 | test=0.9768
# Config: adam-relu-4L-128
#   Ep   1 | loss=0.2689 | val_acc=0.9482
#   Ep   5 | loss=0.0510 | val_acc=0.9730
#   Ep  10 | loss=0.0272 | val_acc=0.9752
#   train=0.9937 | val=0.9752 | test=0.9742
# Config: sgd-tanh-3L-64
#   Ep   1 | loss=0.8946 | val_acc=0.8760
#   Ep   5 | loss=0.2697 | val_acc=0.9205
#   Ep  10 | loss=0.1929 | val_acc=0.9397
#   train=0.9461 | val=0.9397 | test=0.9440
# Config: adam-relu-3L-highLR
#   Ep   1 | loss=0.2796 | val_acc=0.9462
#   Ep   5 | loss=0.1236 | val_acc=0.9600
#   Ep  10 | loss=0.0873 | val_acc=0.9617
#   train=0.9809 | val=0.9653 | test=0.9624
# Config: nadam-tanh-3L-128-wd1e4
#   Ep   1 | loss=0.2730 | val_acc=0.9433
#   Ep   5 | loss=0.0544 | val_acc=0.9730
#   Ep  10 | loss=0.0237 | val_acc=0.9712
#   train=0.9937 | val=0.9742 | test=0.9764
# Config: sgd-sigmoid-2L-64
#   Ep   1 | loss=2.2661 | val_acc=0.2558
#   Ep   5 | loss=1.4498 | val_acc=0.6908
#   Ep  10 | loss=0.7310 | val_acc=0.8222
#   train=0.8222 | val=0.8222 | test=0.8284
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>overfit_gap</td><td>██▃█▇▁</td></tr><tr><td>test_acc</td><td>██▆▇█▁</td></tr><tr><td>train_acc</td><td>██▆▇█▁</td></tr><tr><td>val_acc</td><td>██▆██▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>config</td><td>sgd-sigmoid-2L-64</td></tr><tr><td>overfit_gap</td><td>-0.0062</td></tr><tr><td>test_acc</td><td>0.8284</td></tr><tr><td>train_acc</td><td>0.8222</td></tr><tr><td>val_acc</td><td>0.82217</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-7-global-performance</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/qdsbva8n' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/qdsbva8n</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_031452-qdsbva8n/logs</code>
# ✓ Q2.7 Done!

# %% [markdown]
# ---
# # Q2.8 — Error Analysis + Confusion Matrix (5 Marks)

# %%
#train best model
print('Training best model...')
best_model, _ = build_and_train(
    X_tr, y_tr_oh, X_val, y_val_oh, y_val,
    hidden_sizes=[128,128,128], activation='relu',
    optimizer_name='nadam', learning_rate=0.001,
    epochs=20, batch_size=64, weight_decay=0.0001, use_wandb=False
)

#save as best_model
os.makedirs('models', exist_ok=True)
best_model.save_weights('models/best_model.npy')
cfg_json = {
    'dataset': 'mnist', 'hidden_sizes': [128,128,128],
    'activation': 'relu', 'weight_init': 'xavier',
    'loss': 'cross_entropy', 'weight_decay': 0.0001,
    'optimizer': 'nadam', 'learning_rate': 0.001, 'num_layers': 3
}
with open('models/best_config.json','w') as f: json.dump(cfg_json, f, indent=2)
print('✓ Model saved!')
# Out:
# Training best model...
#   Ep   1 | loss=0.2559 | val_acc=0.9578
#   Ep   5 | loss=0.0504 | val_acc=0.9698
#   Ep  10 | loss=0.0266 | val_acc=0.9760
#   Ep  15 | loss=0.0204 | val_acc=0.9742
#   Ep  20 | loss=0.0177 | val_acc=0.9782
# [INFO] Saved weights → models/best_model.npy
# ✓ Model saved!

# %%
run = wandb.init(project=WANDB_PROJECT, name='q2-8-error-analysis')

y_te_pred = best_model.predict(X_te)
cm_arr    = confusion_matrix(y_te, y_te_pred)
metrics   = compute_metrics(y_te, y_te_pred)
print('Test metrics:', metrics)
wandb.log(metrics)

# ── Plot 1: Confusion matrix ──
fig, ax = plt.subplots(figsize=(9, 7))
im = ax.imshow(cm_arr, cmap='Blues')
plt.colorbar(im, ax=ax)
for i in range(10):
    for j in range(10):
        clr = 'white' if cm_arr[i,j] > cm_arr.max()/2 else 'black'
        ax.text(j, i, str(cm_arr[i,j]), ha='center', va='center', color=clr, fontsize=9)
ax.set_xticks(range(10)); ax.set_yticks(range(10))
ax.set_xticklabels(range(10)); ax.set_yticklabels(range(10))
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
ax.set_title('Confusion Matrix — MNIST Test Set', fontsize=13)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=120)
wandb.log({'confusion_matrix_plot': wandb.Image('confusion_matrix.png')})
plt.show()

#W&B confusion matrix widget
wandb.log({'conf_matrix_wandb': wandb.plot.confusion_matrix(
    probs=None, y_true=y_te.tolist(), preds=y_te_pred.tolist(),
    class_names=[str(i) for i in range(10)]
)})

#plot 2: Gallery of misclassified images
wrong = np.where(y_te_pred != y_te)[0]
fig2, ax2 = plt.subplots(4, 8, figsize=(16, 8))
for i, idx in enumerate(wrong[:32]):
    r, c = divmod(i, 8)
    ax2[r,c].imshow(X_te[idx].reshape(28,28), cmap='Reds')
    ax2[r,c].set_title(f'T:{y_te[idx]} P:{y_te_pred[idx]}', fontsize=7, color='red')
    ax2[r,c].axis('off')
plt.suptitle('Misclassified Examples (T=True, P=Predicted)', fontsize=12)
plt.tight_layout()
plt.savefig('misclassified.png', dpi=100)
wandb.log({'misclassified_gallery': wandb.Image('misclassified.png')})
plt.show()

wandb.finish()
print('✓ Q2.8 Done!')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_033307-o1ls9gc9</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1ls9gc9' target="_blank">q2-8-error-analysis</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1ls9gc9' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1ls9gc9</a>
# Test metrics: {'accuracy': 0.978, 'precision': 0.9780828820194248, 'recall': 0.9779105745007117, 'f1': 0.9779123568942397}
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1</td><td>▁</td></tr><tr><td>precision</td><td>▁</td></tr><tr><td>recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.978</td></tr><tr><td>f1</td><td>0.97791</td></tr><tr><td>precision</td><td>0.97808</td></tr><tr><td>recall</td><td>0.97791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-8-error-analysis</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1ls9gc9' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1ls9gc9</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_033307-o1ls9gc9/logs</code>
# ✓ Q2.8 Done!

# %% [markdown]
# ---
# # Q2.9 — Weight Initialization & Symmetry Breaking (7 Marks)

# %%
import argparse

def track_gradients_50iters(X_tr, y_tr_oh, weight_init_name, num_iters=50):
    """Track grad norms of 5 neurons in first hidden layer for 50 mini-batch steps."""
    args = argparse.Namespace(
        num_layers=3, hidden_size=[128,128,128],
        activation='relu', weight_init=weight_init_name if weight_init_name != 'zeros' else 'random',
        loss='cross_entropy', weight_decay=0.0
    )
    model = NeuralNetwork(cli_args=args)

    if weight_init_name == 'zeros':
        for layer in model.layers:
            layer.W[:] = 0.0
            layer.b[:] = 0.0

    model.optimizer = get_optimizer('sgd', learning_rate=0.01)
    neuron_grads = {i: [] for i in range(5)}

    batch_gen = get_batches(X_tr, y_tr_oh, 128)
    for it in range(num_iters):
        try:
            Xb, yb = next(batch_gen)
        except StopIteration:
            batch_gen = get_batches(X_tr, y_tr_oh, 128)
            Xb, yb = next(batch_gen)

        logits = model.forward(Xb)
        model.backward(yb, logits)
        model.update_weights()

        g = model.layers[0].grad_W   # shape (784, 128)
        for ni in range(5):
            neuron_grads[ni].append(float(np.linalg.norm(g[:, ni])))

    return neuron_grads

run = wandb.init(project=WANDB_PROJECT, name='q2-9-weight-init-symmetry')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
colors5 = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00']

for ax_i, (init_name, title) in enumerate([
    ('zeros',  'Zeros Initialization\n(All lines OVERLAP → symmetry problem!)'),
    ('xavier', 'Xavier Initialization\n(Lines DIFFERENT → symmetry broken!)')
]):
    print(f'Tracking {init_name}...')
    grads = track_gradients_50iters(X_tr, y_tr_oh, init_name)
    for ni in range(5):
        axes[ax_i].plot(range(1,51), grads[ni], label=f'Neuron {ni+1}',
                        color=colors5[ni], lw=2)
    axes[ax_i].set_title(title, fontsize=11)
    axes[ax_i].set_xlabel('Training Iteration')
    axes[ax_i].set_ylabel('Gradient Norm (Layer 1)')
    axes[ax_i].legend(fontsize=9)
    axes[ax_i].grid(alpha=0.3)

plt.suptitle('Symmetry Breaking: Zeros vs Xavier Init', fontsize=13)
plt.tight_layout()
plt.savefig('symmetry_breaking.png', dpi=120)
wandb.log({'symmetry_breaking_plot': wandb.Image('symmetry_breaking.png')})
plt.show()
wandb.finish()
print('✓ Q2.9 Done!')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_033313-o1n2akfl</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1n2akfl' target="_blank">q2-9-weight-init-symmetry</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1n2akfl' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1n2akfl</a>
# Tracking zeros...
# Tracking xavier...
#  View run <strong style="color:#cdcd00">q2-9-weight-init-symmetry</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1n2akfl' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/o1n2akfl</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_033313-o1n2akfl/logs</code>
# ✓ Q2.9 Done!

# %% [markdown]
# ---
# # Q2.10 — Fashion-MNIST Transfer Challenge (5 Marks)

# %%
fashion_configs = [
    {'name':'cfg1-nadam-relu-3L128',  'opt':'nadam', 'lr':0.001,  'l':3, 'sz':128, 'act':'relu', 'wd':0.0001},
    {'name':'cfg2-nadam-relu-4L128',  'opt':'nadam', 'lr':0.0005, 'l':4, 'sz':128, 'act':'relu', 'wd':0.0001},
    {'name':'cfg3-adam-tanh-3L128',   'opt':'adam',  'lr':0.001,  'l':3, 'sz':128, 'act':'tanh', 'wd':0.0},
]

fashion_results = []

for cfg in fashion_configs:
    print(f"\nFashion-MNIST | {cfg['name']}")
    run = wandb.init(
        project=WANDB_PROJECT,
        entity=WANDB_ENTITY,
        name=f"q2-10-fashion-{cfg['name']}",
        config=cfg
    )
    model, hist = build_and_train(
        X_tr_f, y_tr_f_oh, X_val_f, y_val_f_oh, y_val_f,
        hidden_sizes=[cfg['sz']]*cfg['l'], activation=cfg['act'],
        optimizer_name=cfg['opt'], learning_rate=cfg['lr'],
        weight_decay=cfg['wd'], epochs=15, batch_size=128, use_wandb=True
    )
    y_pred_test = model.predict(X_te_f)
    test_met    = compute_metrics(y_te_f, y_pred_test)
    print(f"  Test Acc={test_met['accuracy']:.4f} | F1={test_met['f1']:.4f}")
    wandb.log({'test_accuracy': test_met['accuracy'], 'test_f1': test_met['f1']})
    fashion_results.append({'config': cfg['name'], **test_met})
    wandb.finish()

print('\n── Fashion-MNIST Final Results ──')
for r in fashion_results:
    print(f"  {r['config']:40s} Acc={r['accuracy']:.4f}  F1={r['f1']:.4f}")
print('\n✓ Q2.10 Done!')
# Out:
# Fashion-MNIST | cfg1-nadam-relu-3L128
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_033317-s6ov0iik</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/s6ov0iik' target="_blank">q2-10-fashion-cfg1-nadam-relu-3L128</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/s6ov0iik' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/s6ov0iik</a>
#   Ep   1 | loss=0.5337 | val_acc=0.8675
#   Ep   5 | loss=0.2910 | val_acc=0.8845
#   Ep  10 | loss=0.2369 | val_acc=0.8965
#   Ep  15 | loss=0.2037 | val_acc=0.9030
#   Test Acc=0.8880 | F1=0.8874
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▃▄▅▅▅▆▆▇▇▇▇▇█</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▃▅▄▅▆▇▆▇▇▇▆▇█</td></tr><tr><td>val_loss</td><td>█▅▅▃▃▃▃▂▂▂▁▂▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.888</td></tr><tr><td>test_f1</td><td>0.88743</td></tr><tr><td>train_accuracy</td><td>0.93041</td></tr><tr><td>train_loss</td><td>0.20372</td></tr><tr><td>val_accuracy</td><td>0.903</td></tr><tr><td>val_loss</td><td>0.27767</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-10-fashion-cfg1-nadam-relu-3L128</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/s6ov0iik' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/s6ov0iik</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_033317-s6ov0iik/logs</code>
# Fashion-MNIST | cfg2-nadam-relu-4L128
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_033434-idg83ul1</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/idg83ul1' target="_blank">q2-10-fashion-cfg2-nadam-relu-4L128</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/idg83ul1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/idg83ul1</a>
#   Ep   1 | loss=0.5786 | val_acc=0.8615
#   Ep   5 | loss=0.3025 | val_acc=0.8865
#   Ep  10 | loss=0.2431 | val_acc=0.8923
#   Ep  15 | loss=0.2027 | val_acc=0.8960
#   Test Acc=0.8809 | F1=0.8785
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▄▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▆▇█▇▇</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▁▂▂▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8809</td></tr><tr><td>test_f1</td><td>0.87847</td></tr><tr><td>train_accuracy</td><td>0.92435</td></tr><tr><td>train_loss</td><td>0.20274</td></tr><tr><td>val_accuracy</td><td>0.896</td></tr><tr><td>val_loss</td><td>0.29199</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-10-fashion-cfg2-nadam-relu-4L128</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/idg83ul1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/idg83ul1</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_033434-idg83ul1/logs</code>
# Fashion-MNIST | cfg3-adam-tanh-3L128
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/da6401_assignment_1/wandb/run-20260224_033553-dcxlis9g</code>
# Syncing run <strong><a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/dcxlis9g' target="_blank">q2-10-fashion-cfg3-adam-tanh-3L128</a></strong> to <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a>
#  View run at <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/dcxlis9g' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/dcxlis9g</a>
#   Ep   1 | loss=0.5061 | val_acc=0.8580
#   Ep   5 | loss=0.2990 | val_acc=0.8868
#   Ep  10 | loss=0.2348 | val_acc=0.8922
#   Ep  15 | loss=0.1960 | val_acc=0.8987
#   Test Acc=0.8864 | F1=0.8867
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▃▄▅▄▆▆▆▇▇▇▇▇█</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▃▆▆▄▇▇▆▇█▇▇▆█</td></tr><tr><td>val_loss</td><td>█▅▅▃▃▅▂▁▂▁▁▂▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8864</td></tr><tr><td>test_f1</td><td>0.88672</td></tr><tr><td>train_accuracy</td><td>0.93341</td></tr><tr><td>train_loss</td><td>0.19604</td></tr><tr><td>val_accuracy</td><td>0.89867</td></tr><tr><td>val_loss</td><td>0.28531</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">q2-10-fashion-cfg3-adam-tanh-3L128</strong> at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/dcxlis9g' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1/runs/dcxlis9g</a><br> View project at: <a href='https://wandb.ai/iitm_assigment/da6401-assignment-1' target="_blank">https://wandb.ai/iitm_assigment/da6401-assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_033553-dcxlis9g/logs</code>
# ── Fashion-MNIST Final Results ──
#   cfg1-nadam-relu-3L128                    Acc=0.8880  F1=0.8874
#   cfg2-nadam-relu-4L128                    Acc=0.8809  F1=0.8785
#   cfg3-adam-tanh-3L128                     Acc=0.8864  F1=0.8867
#
# ✓ Q2.10 Done!

# %% [markdown]
# ---
# # Final: Verify Files + Run Inference + Commit to GitHub

# %%
#Verify all files exist
required = [
    'src/ann/__init__.py', 'src/ann/activations.py', 'src/ann/neural_layer.py',
    'src/ann/neural_network.py', 'src/ann/objective_functions.py', 'src/ann/optimizers.py',
    'src/utils/__init__.py', 'src/utils/data_loader.py', 'src/utils/metrics.py',
    'src/train.py', 'src/inference.py',
    'models/best_model.npy', 'models/best_config.json',
    'README.md', 'requirements.txt'
]
all_ok = True
for f in required:
    ok = os.path.exists(f)
    print(f"{'✓' if ok else '✗ MISSING'}  {f}")
    all_ok = all_ok and ok
print('\n✓ All good!' if all_ok else '\n✗ Some files missing!')
# Out:
# ✓  src/ann/__init__.py
# ✓  src/ann/activations.py
# ✓  src/ann/neural_layer.py
# ✓  src/ann/neural_network.py
# ✓  src/ann/objective_functions.py
# ✓  src/ann/optimizers.py
# ✓  src/utils/__init__.py
# ✓  src/utils/data_loader.py
# ✓  src/utils/metrics.py
# ✓  src/train.py
# ✓  src/inference.py
# ✓  models/best_model.npy
# ✓  models/best_config.json
# ✓  README.md
# ✓  requirements.txt
#
# ✓ All good!

# %%
#Test train.py CLI works
# !python src/train.py -d mnist -e 2 -b 64 -o adam -lr 0.001 \
    -nhl 2 -sz 64 -a relu -l cross_entropy -w_i xavier --no_wandb
print('\n✓ train.py CLI works!')
# Out:
# 2026-02-24 03:38:11.306530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771904291.327050   11469 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771904291.333698   11469 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771904291.350381   11469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904291.350408   11469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904291.350412   11469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904291.350415   11469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [info] mnist → Train:54000, Val:6000, Test:10000
# Epoch   1/2 | TrainLoss: 0.3303 | TrainAcc: 0.9546 | ValLoss: 0.1818 | ValAcc: 0.9480 | ValF1: 0.9476
# [INFO] Saved weights → models/best_model.npy
# Epoch   2/2 | TrainLoss: 0.1453 | TrainAcc: 0.9639 | ValLoss: 0.1529 | ValAcc: 0.9545 | ValF1: 0.9542
# [INFO] Saved weights → models/best_model.npy
# [INFO] Loaded weights ← models/best_model.npy
#
# ==================================================
# FINAL TEST RESULTS
#   Accuracy  : 0.9588
#   Precision : 0.9595
#   Recall    : 0.9584
#   F1-Score  : 0.9585
# ==================================================
# Training complete!
#
# ✓ train.py CLI works!

# %%
#Test inference.py CLI works
# !python src/inference.py \
    --model_path models/best_model.npy \
    --dataset mnist --split test
print('\n✓ inference.py CLI works!')
# Out:
# [INFO] Config loaded from: models/best_config.json
# [INFO] Loaded weights ← models/best_model.npy
# 2026-02-24 03:38:25.269689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771904305.289708   11548 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771904305.296133   11548 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771904305.311332   11548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904305.311356   11548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904305.311360   11548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771904305.311364   11548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [info] mnist → Train:54000, Val:6000, Test:10000
# [INFO] Dataset : mnist
# [INFO] Split   : test (10000 samples)
#
# ==================================================
#          INFERENCE RESULTS
# ==================================================
#   Accuracy  : 0.9588  (95.88%)
#   Precision : 0.9595
#   Recall    : 0.9584
#   F1-Score  : 0.9585
#   Loss      : 0.1423
# ==================================================
#
# Per-Class Accuracy:
#   Class  0 (0              ): 0.9898
#   Class  1 (1              ): 0.9912
#   Class  2 (2              ): 0.9360
#   Class  3 (3              ): 0.9792
#   Class  4 (4              ): 0.9654
#   Class  5 (5              ): 0.9585
#   Class  6 (6              ): 0.9645
#   Class  7 (7              ): 0.9728
#   Class  8 (8              ): 0.9189
#   Class  9 (9              ): 0.9078
#
# Evaluation complete!
#
# ✓ inference.py CLI works!

# %%
gh auth login
# Out:
#   File "/tmp/ipython-input-3568707134.py", line 1
#     gh auth login
#        ^
# SyntaxError: invalid syntax

# %%
#push to GitHub
# !git config user.email 'shadabkhanmnw349@gmail.com'
# !git config user.name 'Mohd Shadab'
# !git add -A
# !git commit -m 'DA6401 Assignment 1: Complete MLP implementation with all experiments'
# !git push origin main
print('✓ Pushed to GitHub!')
# Out:
# [main 28566e0] DA6401 Assignment 1: Complete MLP implementation with all experiments
#  203 files changed, 17372 insertions(+)
#  create mode 100644 class_grid.png
#  create mode 100644 confusion_matrix.png
#  create mode 100644 dead_neuron_relu.png
#  create mode 100644 dead_neuron_tanh.png
#  create mode 100644 global_perf.png
#  create mode 100644 loss_comparison.png
#  create mode 100644 misclassified.png
#  create mode 100644 models/best_config.json
#  create mode 100644 models/best_model.npy
#  create mode 100644 optimizer_comparison.png
#  create mode 100644 src/ann/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 src/ann/__pycache__/activations.cpython-312.pyc
#  create mode 100644 src/ann/__pycache__/neural_layer.cpython-312.pyc
#  create mode 100644 src/ann/__pycache__/neural_network.cpython-312.pyc
#  create mode 100644 src/ann/__pycache__/objective_functions.cpython-312.pyc
#  create mode 100644 src/ann/__pycache__/optimizers.cpython-312.pyc
#  create mode 100644 src/utils/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 src/utils/__pycache__/data_loader.cpython-312.pyc
#  create mode 100644 src/utils/__pycache__/metrics.cpython-312.pyc
#  create mode 100644 symmetry_breaking.png
#  create mode 120000 wandb/debug-internal.log
#  create mode 120000 wandb/debug.log
#  create mode 120000 wandb/latest-run
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/config.yaml
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/media/images/class_grid_1_4447b0810696d9f05f64.png
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/media/table/class_sample_table_0_39ce70c91e997786df78.table.json
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/output.log
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/requirements.txt
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_025621-9wewrqaq/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/logs/debug.log
#  create mode 100644 wandb/run-20260224_025621-9wewrqaq/run-9wewrqaq.wandb
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/files/config.yaml
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/files/output.log
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/files/requirements.txt
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_025659-42iabc5e/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/logs/debug.log
#  create mode 100644 wandb/run-20260224_025659-42iabc5e/run-42iabc5e.wandb
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/files/config.yaml
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/files/output.log
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/files/requirements.txt
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_025744-7ib4c4ym/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/logs/debug.log
#  create mode 100644 wandb/run-20260224_025744-7ib4c4ym/run-7ib4c4ym.wandb
#  create mode 100644 wandb/run-20260224_025832-818sng5v/files/config.yaml
#  create mode 100644 wandb/run-20260224_025832-818sng5v/files/output.log
#  create mode 100644 wandb/run-20260224_025832-818sng5v/files/requirements.txt
#  create mode 100644 wandb/run-20260224_025832-818sng5v/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_025832-818sng5v/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_025832-818sng5v/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_025832-818sng5v/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_025832-818sng5v/logs/debug.log
#  create mode 100644 wandb/run-20260224_025832-818sng5v/run-818sng5v.wandb
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/files/config.yaml
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/files/output.log
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/files/requirements.txt
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_025923-zmgrpsh4/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/logs/debug.log
#  create mode 100644 wandb/run-20260224_025923-zmgrpsh4/run-zmgrpsh4.wandb
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/files/config.yaml
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/files/output.log
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030014-cb4kg57x/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/logs/debug.log
#  create mode 100644 wandb/run-20260224_030014-cb4kg57x/run-cb4kg57x.wandb
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/files/config.yaml
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/files/output.log
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030113-sjc3yrhv/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/logs/debug.log
#  create mode 100644 wandb/run-20260224_030113-sjc3yrhv/run-sjc3yrhv.wandb
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/files/config.yaml
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/files/output.log
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030417-bge33wuk/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/logs/debug.log
#  create mode 100644 wandb/run-20260224_030417-bge33wuk/run-bge33wuk.wandb
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/files/config.yaml
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/files/output.log
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030557-6sff9h0j/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/logs/debug.log
#  create mode 100644 wandb/run-20260224_030557-6sff9h0j/run-6sff9h0j.wandb
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/config.yaml
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/media/images/activation_distribution_15_019e5838843abb12d5dc.png
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/output.log
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030727-nc00hhdq/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/logs/debug.log
#  create mode 100644 wandb/run-20260224_030727-nc00hhdq/run-nc00hhdq.wandb
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/config.yaml
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/media/images/activation_distribution_15_40722884b9b8229891e9.png
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/output.log
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/requirements.txt
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_030903-su6nvocy/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/logs/debug.log
#  create mode 100644 wandb/run-20260224_030903-su6nvocy/run-su6nvocy.wandb
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/files/config.yaml
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/files/output.log
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/files/requirements.txt
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_031148-nth07zk7/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/logs/debug.log
#  create mode 100644 wandb/run-20260224_031148-nth07zk7/run-nth07zk7.wandb
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/files/config.yaml
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/files/output.log
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/files/requirements.txt
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_031320-tu5d03tb/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/logs/debug.log
#  create mode 100644 wandb/run-20260224_031320-tu5d03tb/run-tu5d03tb.wandb
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/config.yaml
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/media/images/global_performance_6_4104a5769f13d2253bcb.png
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/output.log
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/requirements.txt
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_031452-qdsbva8n/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/logs/debug.log
#  create mode 100644 wandb/run-20260224_031452-qdsbva8n/run-qdsbva8n.wandb
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/config.yaml
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/media/images/confusion_matrix_plot_1_6254c16bff04293ae9a2.png
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/media/images/misclassified_gallery_3_98d24d8b5eaf6e3b91e1.png
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/media/table/conf_matrix_wandb_table_2_916ea411ac8fd7ea7b97.table.json
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/output.log
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/requirements.txt
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_033307-o1ls9gc9/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/logs/debug.log
#  create mode 100644 wandb/run-20260224_033307-o1ls9gc9/run-o1ls9gc9.wandb
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/config.yaml
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/media/images/symmetry_breaking_plot_0_893884408a78c1ff31be.png
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/output.log
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/requirements.txt
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_033313-o1n2akfl/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/logs/debug.log
#  create mode 100644 wandb/run-20260224_033313-o1n2akfl/run-o1n2akfl.wandb
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/files/config.yaml
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/files/output.log
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/files/requirements.txt
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_033317-s6ov0iik/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/logs/debug.log
#  create mode 100644 wandb/run-20260224_033317-s6ov0iik/run-s6ov0iik.wandb
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/files/config.yaml
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/files/output.log
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/files/requirements.txt
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_033434-idg83ul1/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/logs/debug.log
#  create mode 100644 wandb/run-20260224_033434-idg83ul1/run-idg83ul1.wandb
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/files/config.yaml
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/files/output.log
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/files/requirements.txt
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/files/wandb-metadata.json
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/files/wandb-summary.json
#  create mode 120000 wandb/run-20260224_033553-dcxlis9g/logs/debug-core.log
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/logs/debug-internal.log
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/logs/debug.log
#  create mode 100644 wandb/run-20260224_033553-dcxlis9g/run-dcxlis9g.wandb
# fatal: could not read Username for 'https://github.com': No such device or address
# ✓ Pushed to GitHub!
